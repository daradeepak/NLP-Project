# %%
import time
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
from textblob import TextBlob
import matplotlib.pyplot as plt
import re

def calctime(a):
    return time.time()-a

positive = 0
negative = 0
compound = 0
count = 0

initime = time.time()
plt.ion()

import test

consumerKey = "O6YTYHm94J0hkoNPBW75Cr4ii"
consumerSecret = "Vw2Y0kpQ6jIF6OOidZGV6rYeQwtAwKs8tSQnlkPkdYrz9BQxGB"
accessToken = "1425732915598565387-GzpuPLH6ldqq0wAS60VxGbNpm3NiAC"
accessTokenSecret = "KXSxy6pRb0zMNMYpZhdMMYODIbE5TSmYC3Dk1YZdhMWiP"

class listner(StreamListener):

    def on_data(self, data):
        global initime
        t = int(calctime(initime))
        all_data = json.loads(data)
        tweet = all_data["text"]#.encode("utf-8")
        tweet = "".join(re.findall("[a-zA-Z]+", tweet))
        blob = TextBlob(tweet.strip())

        global count
        global positive
        global negative
        global compound

        count = count+1
        senti = 0

        for sen in blob.sentences:
            senti = senti + sen.sentiment.polarity

            if sen.sentiment.polarity >= 0:
                positive = positive + sen.sentiment.polarity
            else:
                negative = negative + sen.sentiment.polarity

        compound = compound + senti

        print(count)
        print(tweet.strip())
        print(senti)
        print(t)
        print(str(positive) + " " + str(negative) + " " + str(compound))

        plt.axis([0, 70, -20, 20])
        plt.xlabel('Time')
        plt.ylabel('Sentiment')
        plt.plot([t], [positive], [negative], 'go', [t], [negative], 'ro', [compound], 'bo')
        plt.show()
        plt.pause(0.0001)
        if count == 200:
            return False
        else:
            return True
    def on_error(self, status_code):
        print(status_code)

auth = OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)

twitterStream = Stream(auth, listner(count))
twitterStream.filter(track=["Narendra Modi"])
# Out:
# 1
# AnicewordfromPMwouldhavemadeaworldofdifferencetotheentireteamButthenModitakescreditonlywhenhttpstcoVuLWpuyB
# 0.0
# 21
# 0.0 0 0.0
# 2
# RTXycomeonOnlineExamsForCBSEandICSE
# 0.0
# 23
# 0.0 0 0.0
# 3
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 26
# 0.0 0 0.0
# 4
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 28
# 0.0 0 0.0
# 5
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 29
# 0.0 0 0.0
# 6
# RTSylvieDUHVousnavezpashontedelaisserraconterdesmensongessurunechanepubliqueraoultdidierdoitporterplaintecontrev
# 0.0
# 38
# 0.0 0 0.0
# 7
# RTrathormadanlalNarendraModi
# 0.0
# 41
# 0.0 0 0.0
# 8
# RTSukulSouvikOnlineExamsForCBSEandICSEhttpstcoetVEQiNHActivistSukhpalGauravBcbseindiaSonuSood
# 0.0
# 42
# 0.0 0 0.0
# 9
# RTnarendramodiinPMnarendramodiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttps
# 0.0
# 42
# 0.0 0 0.0
# 10
# RTManjeetJangranarendramodi
# 0.0
# 46
# 0.0 0 0.0
# 11
# RTBJPVinodSonkarPMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcooHd
# 0.0
# 50
# 0.0 0 0.0
# 12
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 51
# 0.0 0 0.0
# 13
# RTnarendramodiinPreviousgovernmentsexploitedhealthsectorforpersonalearningPMnarendramodihttpstcobjoXLpPTvmviaNaMo
# 0.0
# 54
# 0.0 0 0.0
# 14
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 63
# 0.0 0 0.0
# 15
# RTBJPVinodSonkarPMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcooHd
# 0.0
# 65
# 0.0 0 0.0
# 16
# PMOIndiaplslookthatmatterPmNarendraModihttpstcoUSARrFKL
# 0.0
# 72
# 0.0 0 0.0
# 17
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 76
# 0.0 0 0.0
# 18
# PMNarendraModilaunchesRscroreprojecttofillcriticalgapsinhealthinfrastructureVaranasiNewshttpstcocmignNDf
# 0.0
# 76
# 0.0 0 0.0
# 19
# RTjulienmontelPendantcetempslenIndeCrationdenouvellesfranchisesdecricketIndianPremierLeagueoffresgag
# 0.0
# 81
# 0.0 0 0.0
# 20
# RTPCMohanMPTheNarendraModiAppisapopularplatformtoinvolvethecommonpopulationofIndiainthegovernanceprocessUserscanc
# 0.0
# 97
# 0.0 0 0.0
# 21
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 100
# 0.0 0 0.0
# 22
# RTflyhighIXUBCCIKirenRijijuneedyoursupporttofurtherdevelopthisCIDCOLtdcricketstadiumnearAurangabad
# 0.0
# 106
# 0.0 0 0.0
# 23
# RTSmartVaranasiHonblePrimeMinisterShriNarendraModiinauguratedVaranasiSmartCityprojectsofoverRsCroremakingthecityw
# 0.0
# 109
# 0.0 0 0.0
# 24
# RTakshuklaNarendraModi
# 0.0
# 115
# 0.0 0 0.0
# 25
# RTNishanthNomatterhowintenselytheycriticiseanddefamehimNarendraModinarendramodideepinsidetheyallknowwellho
# 0.0
# 116
# 0.0 0 0.0
# 26
# RTmarinebharatRPSGgetrightsforLucknowatcroresCVCCapitalwinAmdavadatapproxcroresJustforcomparisonthe
# 0.0
# 116
# 0.0 0 0.0
# 27
# RTKhaledBeydounNarendraModiisxmoreIslamophobicthanDonaldTrumpbutreceivesoftheglobalmediaattentionandoutrage
# 0.0
# 125
# 0.0 0 0.0
# 28
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 131
# 0.0 0 0.0
# 29
# RTDhanrajNathwaniHeartiestcongratulationstoIreliaCompanyPteLtdCVCgroupforgettingIPLNewTeamofAbadwelcometoNarendra
# 0.0
# 136
# 0.0 0 0.0
# 30
# rashtrapatibhvnVPSecretariatNarendraModiisacowardampcriminalampheisunfittobethePMofIndiaasheisihttpstcoZUtgjnvZO
# 0.0
# 160
# 0.0 0 0.0
# 31
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 160
# 0.0 0 0.0
# 32
# RTManjeetJangranarendramodi
# 0.0
# 170
# 0.0 0 0.0
# 33
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 172
# 0.0 0 0.0
# 34
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 174
# 0.0 0 0.0
# 35
# RTBJPVinodSonkarPMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcooHd
# 0.0
# 175
# 0.0 0 0.0
# 36
# RTnarendramodiThankyouPresidentUKhurelsukhforthethoughtfulwishesonVaccineCenturyWearecommittedtointensifyingStrateg
# 0.0
# 184
# 0.0 0 0.0
# 37
# RTnaqvimukhtarPMModiinauguratesninemedicalcollegesinUttarPradeshhttpstcorecXfBxvianarendramodi
# 0.0
# 201
# 0.0 0 0.0
# 38
# CabinetMeetingPMCabinetmeetinghttpstcohqMsIik
# 0.0
# 202
# 0.0 0 0.0
# 39
# RTPCMohanMPTheNarendraModiAppisapopularplatformtoinvolvethecommonpopulationofIndiainthegovernanceprocessUserscanc
# 0.0
# 217
# 0.0 0 0.0
# 40
# NarendraModiCancelISCEISCTermexamsorConductONLINESignthePetitionhttpstcozdKnYmVBUviahttpstcouvmlVuOr
# 0.0
# 224
# 0.0 0 0.0
# 41
# RTrathormadanlalNarendraModi
# 0.0
# 235
# 0.0 0 0.0
# 42
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 236
# 0.0 0 0.0
# 43
# RTakshuklaNarendraModi
# 0.0
# 242
# 0.0 0 0.0
# 44
# NarendraModikoboliyeBdeaayetheSabkasathsabkaViswas
# 0.0
# 242
# 0.0 0 0.0
# 45
# RTOpIndiainPMPMModiCongresshttps
# 0.0
# 245
# 0.0 0 0.0
# 46
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 252
# 0.0 0 0.0
# 47
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 280
# 0.0 0 0.0
# 48
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 286
# 0.0 0 0.0
# 49
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 290
# 0.0 0 0.0
# 50
# RTManjeetJangranarendramodi
# 0.0
# 291
# 0.0 0 0.0
# 51
# RTBJPVinodSonkarPMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcooHd
# 0.0
# 297
# 0.0 0 0.0
# 52
# RTdreamgirlhemaItisthejanamdinofourHonourablePMShriNarendraModijiwhohasledthecountrywithcourageofconvictionevend
# 0.0
# 298
# 0.0 0 0.0
# 53
# OnlineExamForCbse
# 0.0
# 303
# 0.0 0 0.0
# 54
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 304
# 0.0 0 0.0
# 55
# PMNarendraModihaslittleinterestinStockMarketorMutualFundPerLokSabhaAffidavitCashRshttpstcoMIlLKes
# 0.0
# 330
# 0.0 0 0.0
# 56
# RTlaoctavadigitalElpresidenteAndrsManuellopezobradoreselsegundoldermejorcalificadodelmundosolofuesuperadoporelpr
# 0.0
# 335
# 0.0 0 0.0
# 57
# RTkasmPMNarendraModihaslittleinterestinStockMarketorMutualFundPerLokSabhaAffidavitCashRsBankDepos
# 0.0
# 336
# 0.0 0 0.0
# 58
# RTNimishabenBJP
# 0.0
# 347
# 0.0 0 0.0
# 59
# RTPCMohanMPTheNarendraModiAppisapopularplatformtoinvolvethecommonpopulationofIndiainthegovernanceprocessUserscanc
# 0.0
# 348
# 0.0 0 0.0
# 60
# RTnaqvimukhtarThosewhoruleddecadesbeforeusconsideredthehealthsectorameansfortheirpersonalearningandcorruptionPMModi
# 0.0
# 349
# 0.0 0 0.0
# 61
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 356
# 0.0 0 0.0
# 62
# RTKartikeyaTannaVintageNarendraModiTodaysYogiAdityanath
# 0.0
# 364
# 0.0 0 0.0
# 63
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 368
# 0.0 0 0.0
# 64
# RTakshuklaNarendraModi
# 0.0
# 370
# 0.0 0 0.0
# 65
# RTrathormadanlalNarendraModi
# 0.0
# 389
# 0.0 0 0.0
# 66
# RTKhaledBeydounNarendraModiisxmoreIslamophobicthanDonaldTrumpbutreceivesoftheglobalmediaattentionandoutrage
# 0.0
# 394
# 0.0 0 0.0
# 67
# narendramodiPMOIndiaAmitShahHMOIndiaSirareyoutakenanyactionontheCollegiumsystemJusticePandhttpstcoXEefRUhgq
# 0.0
# 399
# 0.0 0 0.0
# 68
# RTNimishabenBJP
# 0.0
# 401
# 0.0 0 0.0
# 69
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 404
# 0.0 0 0.0
# 70
# RTrathormadanlalNarendraModi
# 0.0
# 404
# 0.0 0 0.0
# 71
# RTJaguarETypeetDidierRaoultestunQanonheinGilbertGilbertDeray
# 0.0
# 413
# 0.0 0 0.0
# 72
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 426
# 0.0 0 0.0
# 73
# PMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcorLRWvXEJsm
# 0.0
# 438
# 0.0 0 0.0
# 74
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 443
# 0.0 0 0.0
# 75
# NarendraModiCancelISCEISCTermexamsorConductONLINEhttpstcoSBSYKaGNVvviaChangeOrgIndia
# 0.0
# 454
# 0.0 0 0.0
# 76
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 457
# 0.0 0 0.0
# 77
# RTMikeOviedoAMLOelsegundoldermejorcalificadodelmundosesituenslopordebajodelprimerministrodelaIndiaNarend
# 0.0
# 459
# 0.0 0 0.0
# 78
# PreviousgovernmentsexploitedhealthsectorforpersonalearningPMNarendraModihttpstcoIQYBACLJvviaNahttpstcopyLuyoh
# 0.0
# 459
# 0.0 0 0.0
# 79
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 466
# 0.0 0 0.0
# 80
# FightingStigmaOnVaranasivisitModikicksoffmegahealthinframissionTribuneIndiaPrimeMinisterNarehttpstcohEkekYt
# 0.0
# 499
# 0.0 0 0.0
# 81
# RTMikeOviedoAMLOelsegundoldermejorcalificadodelmundosesituenslopordebajodelprimerministrodelaIndiaNarend
# 0.0
# 503
# 0.0 0 0.0
# 82
# RTflyhighIXUBCCIKirenRijijuneedyoursupporttofurtherdevelopthisCIDCOLtdcricketstadiumnearAurangabad
# 0.0
# 509
# 0.0 0 0.0
# 83
# RTveroniquegenestHolevilaincomplotisteCommentpeutonencorecoutercementeurpatentChaquemotquilprononceestunefaken
# 0.0
# 513
# 0.0 0 0.0
# 84
# RTSmartVaranasiHonblePrimeMinisterShriNarendraModiinauguratedVaranasiSmartCityprojectsofoverRshttpstcouxmQnNoAw
# 0.0
# 518
# 0.0 0 0.0
# 85
# httpstcohmxztsqe
# 0.0
# 518
# 0.0 0 0.0
# 86
# RTKashiAlokRTSmartVaranasiHonblePrimeMinisterShriNarendraModiinauguratedVaranasiSmartCityprojecthttpstcoseAxsReOi
# 0.0
# 520
# 0.0 0 0.0
# 87
# RTnarendramodiinPMnarendramodiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttps
# 0.0
# 521
# 0.0 0 0.0
# 88
# RTRahulRCModiInUP
# 0.0
# 522
# 0.0 0 0.0
# 89
# RTVeerRudraPMModiexpresseshissinceregratitudetothedoctorsnursesnallCOVIDfrontlineworkersasthecountryachievesre
# 0.0
# 523
# 0.0 0 0.0
# 90
# ShriNarendraModiHonourablePrimeMinisterOfIndiaInstallationOfNetajisStatueNearIndiaGateWarMemorhttpstcoMLoJXXoNhE
# 0.0
# 525
# 0.0 0 0.0
# 91
# RTnarendramodiinPreviousgovernmentsexploitedhealthsectorforpersonalearningPMnarendramodihttpstcobjoXLpPTvmviaNaMo
# 0.0
# 526
# 0.0 0 0.0
# 92
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 555
# 0.0 0 0.0
# 93
# RTMFenNormandieCestfouJesprequeraoultdidiervaporterplainte
# 0.0
# 558
# 0.0 0 0.0
# 94
# RTGappistanRadioInNarendraModisIndiayoucanburstcrackersafteranIndiancricketdefeatbutnotonDiwaliThatisthebruta
# 0.0
# 570
# 0.0 0 0.0
# 95
# RTLiveLawIndiaSupremeCourttohearapleabyZakiaAhsanJafriwidowofCongressMPEhsanJafriagainstthecleanchitgiventoPM
# 0.0
# 575
# 0.0 0 0.0
# 96
# RTYourTimeUpIPSBJPgovtinsecondturnhasbeenturningouttobethegreatestdisasterforourHinduCauseNarendraModihasbeenup
# 0.0
# 579
# 0.0 0 0.0
# 97
# RTrathormadanlalNarendraModi
# 0.0
# 595
# 0.0 0 0.0
# 98
# httpstcoScnkNVGbU
# 0.0
# 614
# 0.0 0 0.0
# 99
# RealVikas
# 0.0
# 625
# 0.0 0 0.0
# 100
# PMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcolevIngWMKL
# 0.0
# 629
# 0.0 0 0.0
# 101
# RTMikeOviedoAMLOelsegundoldermejorcalificadodelmundosesituenslopordebajodelprimerministrodelaIndiaNarend
# 0.0
# 630
# 0.0 0 0.0
# 102
# RTnarendramodiinBigboosttomedicaleducationinUPasPrimeMinisterNarendraModiinauguratesnewmedicalcollegesHeadtoYour
# 0.0
# 632
# 0.0 0 0.0
# 103
# RTMahiyankImagineDhoniplayinginNarendraModistadiuminAhmedabadwithcrowdandpeoplechantingDhoniDhoni
# 0.0
# 634
# 0.0 0 0.0
# 104
# PMModiinauguratesmedicalcollegesinUPsaysunderlastgovtcycleofcorruptionranhourshttpstcoAroWfFB
# 0.0
# 635
# 0.0 0 0.0
# 105
# RTRahulRCModiInUP
# 0.0
# 641
# 0.0 0 0.0
# 106
# RTthecaravanindiaReplugISincetheNarendraModiledBharatiyaJanataPartygovernmentcametopowerthenetworthofJayShahsfir
# 0.0
# 654
# 0.0 0 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18480/150003952.py in <module>
#      77
#      78 twitterStream = Stream(auth, listner(count))
# ---> 79 twitterStream.filter(track=["Narendra Modi"])
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# c:\users\hp\appdata\local\programs\python\python39\lib\http\client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# c:\users\hp\appdata\local\programs\python\python39\lib\http\client.py in readinto(self, b)
#     491
#     492         if self.chunked:
# --> 493             return self._readinto_chunked(b)
#     494
#     495         if self.length is not None:
#
# c:\users\hp\appdata\local\programs\python\python39\lib\http\client.py in _readinto_chunked(self, b)
#     586         try:
#     587             while True:
# --> 588                 chunk_left = self._get_chunk_left()
#     589                 if chunk_left is None:
#     590                     return total_bytes
#
# c:\users\hp\appdata\local\programs\python\python39\lib\http\client.py in _get_chunk_left(self)
#     554                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     555             try:
# --> 556                 chunk_left = self._read_next_chunk_size()
#     557             except ValueError:
#     558                 raise IncompleteRead(b'')
#
# c:\users\hp\appdata\local\programs\python\python39\lib\http\client.py in _read_next_chunk_size(self)
#     514     def _read_next_chunk_size(self):
#     515         # Read the next chunk size from the file
# --> 516         line = self.fp.readline(_MAXLINE + 1)
#     517         if len(line) > _MAXLINE:
#     518             raise LineTooLong("chunk size")
#
# c:\users\hp\appdata\local\programs\python\python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\users\hp\appdata\local\programs\python\python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
