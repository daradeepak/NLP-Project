# %%
import tweepy
from textblob import  TextBlob
import json

consumer_key= "O6YTYHm94J0hkoNPBW75Cr4ii"
consumer_secret= "Vw2Y0kpQ6jIF6OOidZGV6rYeQwtAwKs8tSQnlkPkdYrz9BQxGB"

access_token="1425732915598565387-GzpuPLH6ldqq0wAS60VxGbNpm3NiAC"
access_token_secret="KXSxy6pRb0zMNMYpZhdMMYODIbE5TSmYC3Dk1YZdhMWiP"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)


class StdOutListener(tweepy.streaming.StreamListener):
    counter = 0

    def on_data(self, data):
        tweet = json.loads(data)
        analysis = TextBlob(tweet['text'])
        print(tweet['text'])
        print(analysis.sentiment)
        print('-------------------------------------------------------------')
        return True

    def on_error(self, status):
        print(status)

    def on_status(self, status):
        global counter
        counter = counter + 1
        if counter < 5:
            return True
        else:
            return False

myStream = tweepy.Stream(auth = api.auth, listener = StdOutListener())
myStream.filter(track = ["Trump"], languages=["en"])


public_tweets = api.search('Trump')

for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print('-------------------------------------------------------------')
# Out:
# @GregAbbott_TX The same shit was happening when trump was president.
# Sentiment(polarity=-0.1, subjectivity=0.4625)
# -------------------------------------------------------------
# RT @TheValuesVoter: In my experience, nothing seems to anger Trump supporters more than facts that they can’t refute that challenge the thi…
# Sentiment(polarity=-0.09999999999999998, subjectivity=0.35)
# -------------------------------------------------------------
# @JackPosobiec Really couldn’t you come up with something better than to bash Trump for your campaign. Most people v… https://t.co/BpW8EJlk5c
# Sentiment(polarity=0.39999999999999997, subjectivity=0.39999999999999997)
# -------------------------------------------------------------
# RT @donwinslow: Why did we concede and accept the term "insurrection" for January 6?
#
# It was domestic terrorist attack violently waged by s…
# Sentiment(polarity=-0.4, subjectivity=0.55)
# -------------------------------------------------------------
# ...
